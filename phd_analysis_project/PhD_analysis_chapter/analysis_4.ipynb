# %%
# 1. EXAMINE STARTING AND ENDING POINTS OF PHRASES

# %%
import pandas as pd
from textwrap import wrap
#import seaborn
import numpy as np
from IPython.display import Image
from IPython.core.display import HTML
from IPython.core.display import Image 
from IPython.display import display, HTML
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.mpl_style', 'default')
pd.set_option('display.notebook_repr_html', True)
import data_methods
import warnings
warnings.filterwarnings("ignore")
def _repr_latex_(self):
    return self.to_latex()
pd.DataFrame._repr_latex_ = _repr_latex_  

from music21 import *

# %matplotlib inline
# %pylab inline
plt.style.use('ggplot')


plt.rcParams["font.family"] = "arial"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#UTILITY TO MANAGE LABEL WRAPPING
labels=["Number of phrases starting at this measure location",
        "Number of phrases ending at this measure location",
       ]
labels = [ '\n'.join(wrap(l, 20)) for l in labels ]

# %%
all_melodies = pd.read_pickle('./data_frames/all_melodies_frame')

# %%
# It is also possible examine locations, starting locations
# shows phrase vehicle of variety - enforces previous analysis
# EXAMINE PHRASE STARTING LOCATIONS IN MEASURE ACROSS KJ SOLOS
# This challenges what we know - don't play on the on the one, jarrett doesn't do this, 
# allthough the two is is 

ax = all_melodies["Measure location in which phrase begins"].hist(bins=50)
ax.set_title('Phrase starting locations within measures across all solos', fontsize=12)
ax.set_xlabel("Measure location in which phrase begins")
ax.set_ylabel(labels[0])

# %%
# EXAMINE PHRASE STARTING LOCATIONS IN EACH SOLO
# note the diff to sdmpwc
 
fig, axes = plt.subplots(nrows=5, ncols=2)
fig.set_figheight(45)
fig.set_figwidth(40)
fig.suptitle('Phrase starting locations within measures', fontsize=30)



ax = all_melodies[(all_melodies['Title'] == 'Autumn Leaves') & (all_melodies['Performer collection'] == 'Still Live')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[0,0])
axes[0,0].set_title('Autumn Leaves (Still Live version)', fontsize=30)
axes[0,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[0,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Autumn Leaves') & (all_melodies['Performer collection'] == 'Tokyo 96')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[0,1])
axes[0,1].set_title('Autumn Leaves (Tokyo 96 version)', fontsize=30)
axes[0,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[0,1].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'If I Were A Bell')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[1,0])
axes[1,0].set_title('If I Were A Bell', fontsize=30)
axes[1,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[1,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Days Of Wine And Roses')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[1,1])
axes[1,1].set_title('Days Of Wine And Roses', fontsize=30)
axes[1,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[1,1].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Groovin High')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[2,0])
axes[2,0].set_title('Groovin High', fontsize=30)
axes[2,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[2,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Stella By Starlight')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[2,1])
axes[2,1].set_title('Stella By Starlight', fontsize=30)
axes[2,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[2,1].set_ylabel(labels[0], fontsize=25)


ax = all_melodies[(all_melodies['Title'] == 'In Love In Vain')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[3,0])
axes[3,0].set_title('In Love In Vain', fontsize=30)
axes[3,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[3,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'My Funny Valentine')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[3,1])
axes[3,1].set_title('My Funny Valentine', fontsize=30)
axes[3,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[3,1].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'All The Things You Are')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[4,0])
axes[4,0].set_title('All The Things You Are', fontsize=30)
axes[4,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[4,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Someday My Prince Will Come')]["Measure location in which phrase begins"].hist(bins=50, ax=axes[4,1])
axes[4,1].set_title('Someday My Prince Will Come', fontsize=30)
axes[4,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[4,1].set_ylabel(labels[0], fontsize=25)

# %%
# EXAMINE PHRASE ENDING LOCATIONS IN MEASURE ACROSS CORPUS

ax = all_melodies["Measure location in which phrase ends"].hist(bins=50)
ax.set_title('Phrase ending locations within measures across all solos', fontsize=12)
ax.set_xlabel("Measure location in which phrase ends")
ax.set_ylabel(labels[1])

# %%
# EXAMINE PHRASE STARTING LOCATIONS IN EACH SOLO
 
fig, axes = plt.subplots(nrows=5, ncols=2)
fig.set_figheight(45)
fig.set_figwidth(40)
fig.suptitle('Phrase starting locations within measures', fontsize=30)



ax = all_melodies[(all_melodies['Title'] == 'Autumn Leaves') & (all_melodies['Performer collection'] == 'Still Live')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[0,0])
axes[0,0].set_title('Autumn Leaves (Still Live version)', fontsize=30)
axes[0,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[0,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Autumn Leaves') & (all_melodies['Performer collection'] == 'Tokyo 96')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[0,1])
axes[0,1].set_title('Autumn Leaves (Tokyo 96 version)', fontsize=30)
axes[0,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[0,1].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'If I Were A Bell')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[1,0])
axes[1,0].set_title('If I Were A Bell', fontsize=30)
axes[1,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[1,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Days Of Wine And Roses')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[1,1])
axes[1,1].set_title('Days Of Wine And Roses', fontsize=30)
axes[1,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[1,1].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Groovin High')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[2,0])
axes[2,0].set_title('Groovin High', fontsize=30)
axes[2,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[2,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Stella By Starlight')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[2,1])
axes[2,1].set_title('Stella By Starlight', fontsize=30)
axes[2,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[2,1].set_ylabel(labels[0], fontsize=25)


ax = all_melodies[(all_melodies['Title'] == 'In Love In Vain')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[3,0])
axes[3,0].set_title('In Love In Vain', fontsize=30)
axes[3,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[3,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'My Funny Valentine')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[3,1])
axes[3,1].set_title('My Funny Valentine', fontsize=30)
axes[3,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[3,1].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'All The Things You Are')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[4,0])
axes[4,0].set_title('All The Things You Are', fontsize=30)
axes[4,0].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[4,0].set_ylabel(labels[0], fontsize=25)

ax = all_melodies[(all_melodies['Title'] == 'Someday My Prince Will Come')]["Measure location in which phrase ends"].hist(bins=50, ax=axes[4,1])
axes[4,1].set_title('Someday My Prince Will Come', fontsize=30)
axes[4,1].set_xlabel("Measure location in which phrase begins", fontsize=30)
axes[4,1].set_ylabel(labels[0], fontsize=25)
